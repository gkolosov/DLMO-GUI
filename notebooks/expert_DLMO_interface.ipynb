# %% [markdown]
# # DLMO Expert labels

# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
from dlmo_expert_GUI import DlmoGui
import matplotlib.pyplot as plt
# %matplotlib widget

from IPython.core.display import display, HTML
#display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /Users/koloss/Desktop/DLMO-GUI

# %%
plt.close('all')
DlmoGui(show_dates=False)
# Out:
# DlmoGui(children=(VBox(children=(HBox(children=(RadioButtons(description='Confidence:', options=('🟢 High', '🟠 …
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
import pickle

PATH_SAVE = "data/expert_labels.pickle"

with open(PATH_SAVE, 'rb') as handle:
    b = pickle.load(handle)

# %%
import pandas as pd
from dlmo_expert_GUI import PATH,get_data
import numpy as np

# %%
np.arange(0, 10, 1.25)
# Out:
# array([0.  , 1.25, 2.5 , 3.75, 5.  , 6.25, 7.5 , 8.75])

# %%
np.arange(0, df.index[-1], 5/60) + np.array(df.index[-1]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-dd943291af6c> in <module>
# ----> 1 np.arange(0, df.index[-1], 5/60) + np.array[df.index[-1]]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
df = get_data(n=1)
df.index =(df.index-df.index[0])
df.index =(df.index-df.index[0])/ np.timedelta64(1, 'h')
df
# Out:
#              melatonin
# clock_time
# 0.000000      9.820802
# 0.583333      9.203606
# 1.566667      5.336201
# 2.583333      5.586888
# 3.583333      5.943190
# 4.583333      5.597549
# 5.583333      5.185965
# 6.583333      5.148911
# 7.616667      4.306975
# 8.583333      5.498357
# 9.583333      5.480131
# 10.583333     4.898394
# 11.583333     8.016290
# 12.583333    75.653363
# 13.600000   130.345116
# 14.583333   129.199264
# 15.583333   130.540758
# 16.666667   127.429646
# 17.650000   116.336204
# 18.666667    85.184812
# 19.683333    73.749995
# 20.650000    63.272285
# 21.583333    47.820374
# 22.566667    19.572128
# 23.566667     7.588373
# 24.583333     5.979298
# 25.583333     5.395498
# 26.583333     6.755728
# 27.583333     6.221978
# 28.583333     5.587648
# 29.583333     5.166389
# 30.600000     5.665793
# 31.583333     5.182949
# 32.583333     5.240268
# 33.583333     6.703997

# %%
np.linspace

# %%
df = get_data(n=1)
df.index = df.index-df.index[0]
start_date = df.index[0]
end_date = df.index[-1]




dates = pd.date_range(start_date, end_date, freq='5min')
options = [(date.strftime('%H : %M'), date) for date in dates]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-e9f4ff28ab44> in <module>
#       3 start_date = df.index[0]
#       4 end_date = df.index[-1]
# ----> 5 dates = pd.date_range(start_date, end_date, freq='5min')
#       6 options = [(date.strftime('%H : %M'), date) for date in dates]
#
# ~/opt/anaconda3/envs/mignot_lab/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py in date_range(start, end, periods, freq, tz, normalize, name, closed, inclusive, **kwargs)
#    1068         freq = "D"
#    1069
# -> 1070     dtarr = DatetimeArray._generate_range(
#    1071         start=start,
#    1072         end=end,
#
# ~/opt/anaconda3/envs/mignot_lab/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in _generate_range(cls, start, end, periods, freq, tz, normalize, ambiguous, nonexistent, inclusive)
#     410
#     411         if start is not None:
# ...

# %%
dates
# Out:
# DatetimeIndex(['2022-01-01 07:25:00', '2022-01-01 07:30:00',
#                '2022-01-01 07:35:00', '2022-01-01 07:40:00',
#                '2022-01-01 07:45:00', '2022-01-01 07:50:00',
#                '2022-01-01 07:55:00', '2022-01-01 08:00:00',
#                '2022-01-01 08:05:00', '2022-01-01 08:10:00',
#                ...
#                '2022-01-02 16:15:00', '2022-01-02 16:20:00',
#                '2022-01-02 16:25:00', '2022-01-02 16:30:00',
#                '2022-01-02 16:35:00', '2022-01-02 16:40:00',
#                '2022-01-02 16:45:00', '2022-01-02 16:50:00',
#                '2022-01-02 16:55:00', '2022-01-02 17:00:00'],
#               dtype='datetime64[ns]', length=404, freq='5T')

# %%
pd.to_datetime(df['clock_time']) -
# Out:
# 0     2022-01-01 07:25:00.000
# 1     2022-01-01 08:00:00.000
# 2     2022-01-01 08:59:00.000
# 3     2022-01-01 10:00:00.000
# 4     2022-01-01 11:00:00.000
#                 ...
# 140   1900-10-21 18:32:59.989
# 141   1900-10-21 19:31:59.989
# 142   1900-10-21 20:30:59.989
# 143   1900-10-21 21:28:59.989
# 144   1900-10-21 22:29:59.989
# Name: clock_time, Length: 145, dtype: datetime64[ns]

# %%
df['clock_time'] - df['clock_time'].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/mignot_lab/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-b5e6c44beb96> in <module>
# ----> 1 df['clock_time'] - df['clock_time'].min()
#
# ~/opt/anaconda3/envs/mignot_lab/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ...
