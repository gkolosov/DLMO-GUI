# %% [markdown]
# # DLMO Expert labels

# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
from dlmo_expert_GUI import DlmoGui
import matplotlib.pyplot as plt
# %matplotlib widget
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/koloss/Desktop

# %%
plt.close('all')
DlmoGui()
# Out:
# DlmoGui(children=(VBox(children=(VBox(children=(SelectionRangeSlider(description='DLMO Range', index=(0, 276),…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import pickle

PATH_SAVE = "all_data/rawData/expert_labels.pickle"

with open(PATH_SAVE, 'rb') as handle:
    b = pickle.load(handle)
b[4].dlmo
# Out:
# Timestamp('2022-01-02 01:59:00', freq='5T')
