# %% [markdown]
# # DLMO Expert labels

# %%
# %load_ext autoreload
# %autoreload 2
# %cd ..
from dlmo_expert_GUI import DlmoGui
import matplotlib.pyplot as plt
# %matplotlib widget

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /Users/koloss/Desktop/DLMO-GUI
# <style>.container { width:100% !important; }</style>

# %%
plt.close('all')
DlmoGui()
# Out:
# DlmoGui(children=(VBox(children=(VBox(children=(SelectionRangeSlider(description='DLMO Range', index=(69, 207)…
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
import pickle

PATH_SAVE = "data/expert_labels.pickle"

with open(PATH_SAVE, 'rb') as handle:
    b = pickle.load(handle)
